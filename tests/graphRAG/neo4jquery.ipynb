# %% [markdown]
# This is to have a track of which cypher queries that have been run more easily and test the output

# %%
from neo4j import GraphDatabase
from langchain_neo4j import Neo4jGraph

# %%
url = "bolt://localhost:7687"
username = "neo4j"
password= "neo4j"
graph = Neo4jGraph(url=url, username=username, password=password)
driver = GraphDatabase.driver(url, auth=(username, password))
session = driver.session()

# %%
def queryNeo4j(driver, query):
    """Runs a single Cypher query."""
    
    with driver.session() as session:
        try:
            session.run(query)
            
        except Exception as e:
            print(f"Error executing query: {e}")

# %%
#strips out the http://w3id.org/anett-o/

queryNeo4j(driver, """
MATCH (n)
WHERE n.uri STARTS WITH 'http://w3id.org/annett-o/'
SET n.uri = SPLIT(n.uri, '/')[SIZE(SPLIT(n.uri, '/')) - 1]
""")

# %%
graph.get_structured_schema
# Out:
# {'node_props': {'Resource': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__layer_num_units', 'type': 'LIST'},
#    {'property': 'ns0__eval_score', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate', 'type': 'LIST'},
#    {'property': 'owl__qualifiedCardinality', 'type': 'LIST'},
#    {'property': 'owl__minQualifiedCardinality', 'type': 'LIST'},
#    {'property': 'ns0__dropout_rate', 'type': 'LIST'},
#    {'property': 'rdfs__comment', 'type': 'LIST'},
#    {'property': 'ns0__labels_count', 'type': 'LIST'},
#    {'property': 'ns0__labels_dtype', 'type': 'LIST'},
#    {'property': 'ns0__normal_sigma', 'type': 'LIST'},
#    {'property': 'ns0__normal_mu', 'type': 'LIST'},
#    {'property': 'ns0__data_sample_features', 'type': 'LIST'},
#    {'property': 'ns0__data_sample_dimensionality', 'type': 'LIST'},
#    {'property': 'ns0__momentum', 'type': 'LIST'},
#    {'property': 'ns0__number_of_epochs', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate_decay_epochs', 'type': 'LIST'},
#    {'property': 'ns0__batch_size', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate_decay', 'type': 'LIST'},
#    {'property': 'ns0__data_description', 'type': 'LIST'},
#    {'property': 'ns0__data_samples', 'type': 'LIST'},
#    {'property': 'ns0__data_location', 'type': 'LIST'},
#    {'property': 'ns0__is_transient_dataset', 'type': 'LIST'},
#    {'property': 'ns0__num_of_iterations', 'type': 'LIST'},
#    {'property': 'owl__maxQualifiedCardinality', 'type': 'LIST'},
#    {'property': 'ns0__has_bias', 'type': 'LIST'}],
#   '_GraphConfig': [{'property': '_dataTypePropertyLabel', 'type': 'STRING'},
#    {'property': '_subPropertyOfRel', 'type': 'STRING'},
#    {'property': '_classNamePropName', 'type': 'STRING'},
#    {'property': '_handleVocabUris', 'type': 'INTEGER'},
#    {'property': '_applyNeo4jNaming', 'type': 'BOOLEAN'},
#    {'property': '_relNamePropName', 'type': 'STRING'},
#    {'property': '_domainRel', 'type': 'STRING'},
#    {'property': '_keepLangTag', 'type': 'BOOLEAN'},
#    {'property': '_keepCustomDataTypes', 'type': 'BOOLEAN'},
#    {'property': '_handleMultival', 'type': 'INTEGER'},
#    {'property': '_objectPropertyLabel', 'type': 'STRING'},
#    {'property': '_rangeRel', 'type': 'STRING'},
#    {'property': '_classLabel', 'type': 'STRING'},
#    {'property': '_handleRDFTypes', 'type': 'INTEGER'},
#    {'property': '_subClassOfRel', 'type': 'STRING'}],
#   '_NsPrefDef': [{'property': 'rdf', 'type': 'STRING'},
#    {'property': 'rdfs', 'type': 'STRING'},
#    {'property': 'ns0', 'type': 'STRING'},
#    {'property': 'owl', 'type': 'STRING'}],
#   'owl__NamedIndividual': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__layer_num_units', 'type': 'LIST'},
#    {'property': 'ns0__eval_score', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate', 'type': 'LIST'},
#    {'property': 'ns0__dropout_rate', 'type': 'LIST'},
#    {'property': 'ns0__labels_count', 'type': 'LIST'},
#    {'property': 'ns0__labels_dtype', 'type': 'LIST'},
#    {'property': 'ns0__normal_sigma', 'type': 'LIST'},
#    {'property': 'ns0__normal_mu', 'type': 'LIST'},
#    {'property': 'ns0__data_sample_features', 'type': 'LIST'},
#    {'property': 'ns0__data_sample_dimensionality', 'type': 'LIST'},
#    {'property': 'ns0__momentum', 'type': 'LIST'},
#    {'property': 'ns0__number_of_epochs', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate_decay_epochs', 'type': 'LIST'},
#    {'property': 'ns0__batch_size', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate_decay', 'type': 'LIST'},
#    {'property': 'ns0__data_description', 'type': 'LIST'},
#    {'property': 'ns0__data_samples', 'type': 'LIST'},
#    {'property': 'ns0__data_location', 'type': 'LIST'},
#    {'property': 'ns0__is_transient_dataset', 'type': 'LIST'},
#    {'property': 'ns0__num_of_iterations', 'type': 'LIST'},
#    {'property': 'ns0__has_bias', 'type': 'LIST'}],
#   'ns0__DatasetPipe': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__CloneLayer': [{'property': 'ns0__layer_num_units', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'}],
#   'ns0__MinObjectiveFunction': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__FunctionalProperty': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__DatatypeProperty': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'rdfs__comment', 'type': 'LIST'}],
#   'owl__ObjectProperty': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__AsymmetricProperty': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__IrreflexiveProperty': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__NumericalDigits': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__EvaluationResult': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__eval_score', 'type': 'LIST'}],
#   'ns0__GradientDescent': [{'property': 'ns0__learning_rate', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'}],
#   'ns0__InputLayer': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__layer_num_units', 'type': 'LIST'}],
#   'ns0__Network': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Image': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Accuracy': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__AllDisjointProperties': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__Class': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'rdfs__comment', 'type': 'LIST'}],
#   'owl__InverseFunctionalProperty': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__DropoutLayer': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__dropout_rate', 'type': 'LIST'}],
#   'ns0__OutputLayer': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__layer_num_units', 'type': 'LIST'}],
#   'ns0__FullyConnectedLayer': [{'property': 'ns0__layer_num_units',
#     'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__has_bias', 'type': 'LIST'}],
#   'ns0__TrainedWeights': [{'property': 'uri', 'type': 'STRING'}],
#   'rdfs__Datatype': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__AllDisjointClasses': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__BatchNormLayer': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Relu': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Labelset': [{'property': 'ns0__labels_count', 'type': 'LIST'},
#    {'property': 'ns0__labels_dtype', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__is_transient_dataset', 'type': 'LIST'}],
#   'ns0__Dataset': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__data_sample_dimensionality', 'type': 'LIST'},
#    {'property': 'ns0__data_sample_features', 'type': 'LIST'},
#    {'property': 'ns0__data_description', 'type': 'LIST'},
#    {'property': 'ns0__data_samples', 'type': 'LIST'},
#    {'property': 'ns0__data_location', 'type': 'LIST'},
#    {'property': 'ns0__is_transient_dataset', 'type': 'LIST'}],
#   'ns0__TrainedModel': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Gaussian': [{'property': 'ns0__normal_sigma', 'type': 'LIST'},
#    {'property': 'ns0__normal_mu', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'}],
#   'owl__Restriction': [{'property': 'owl__qualifiedCardinality',
#     'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'},
#    {'property': 'owl__minQualifiedCardinality', 'type': 'LIST'},
#    {'property': 'owl__maxQualifiedCardinality', 'type': 'LIST'}],
#   'ns0__Categorical': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__ANNConfiguration': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__SymmetricProperty': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__MSE': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Adversarial': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__RandomNoiseDataset': [{'property': 'ns0__data_sample_features',
#     'type': 'LIST'},
#    {'property': 'ns0__data_sample_dimensionality', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'}],
#   'ns0__Reconstruction': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__BinaryCrossEntropy': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__L2RegularizerFunction': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Momentum': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__momentum', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate', 'type': 'LIST'}],
#   'ns0__Discrimination': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Sigmoid': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__CostFunction': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__TrainingSingle': [{'property': 'uri', 'type': 'STRING'},
#    {'property': 'ns0__number_of_epochs', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate_decay_epochs', 'type': 'LIST'},
#    {'property': 'ns0__batch_size', 'type': 'LIST'},
#    {'property': 'ns0__learning_rate_decay', 'type': 'LIST'}],
#   'ns0__Generation': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__TrainingSingleForwardOnly': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__TrainingStrategy': [{'property': 'uri', 'type': 'STRING'}],
#   'owl__Ontology': [{'property': 'rdfs__comment', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'}],
#   'ns0__SoftMax': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__TrainingSession': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Tanh': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__ConcatLayer': [{'property': 'ns0__layer_num_units', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'}],
#   'ns0__CategoricalCrossEntropy': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__SupervisedClassification': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__Clustering': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__IterateFor': [{'property': 'ns0__num_of_iterations', 'type': 'LIST'},
#    {'property': 'uri', 'type': 'STRING'}],
#   'ns0__Linear': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__ParzenWindow': [{'property': 'uri', 'type': 'STRING'}],
#   'ns0__TrainingLoop': [{'property': 'uri', 'type': 'STRING'}]},
#  'rel_props': {},
#  'relationships': [{'start': 'Resource',
#    'type': 'ns0__joinsDataSet',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__joinsDataSet',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__joinsDataSet', 'end': 'ns0__Dataset'},
#   {'start': 'Resource',
#    'type': 'ns0__joinsDataSet',
#    'end': 'ns0__RandomNoiseDataset'},
#   {'start': 'Resource', 'type': 'ns0__joinsLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__joinsLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__joinsLayer', 'end': 'ns0__OutputLayer'},
#   {'start': 'Resource', 'type': 'ns0__joinsLayer', 'end': 'ns0__InputLayer'},
#   {'start': 'Resource', 'type': 'ns0__joinsLayer', 'end': 'ns0__DatasetPipe'},
#   {'start': 'Resource', 'type': 'ns0__previousLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__previousLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__DropoutLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__ConcatLayer'},
#   {'start': 'Resource', 'type': 'ns0__nextLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__nextLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'Resource', 'type': 'ns0__nextLayer', 'end': 'ns0__DropoutLayer'},
#   {'start': 'Resource', 'type': 'ns0__nextLayer', 'end': 'ns0__CloneLayer'},
#   {'start': 'Resource', 'type': 'ns0__nextLayer', 'end': 'ns0__OutputLayer'},
#   {'start': 'Resource', 'type': 'ns0__nextLayer', 'end': 'ns0__ConcatLayer'},
#   {'start': 'Resource', 'type': 'ns0__sameLayerAs', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__sameLayerAs',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__sameLayerAs', 'end': 'ns0__CloneLayer'},
#   {'start': 'Resource', 'type': 'ns0__sameLayerAs', 'end': 'ns0__InputLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__DropoutLayer'},
#   {'start': 'Resource', 'type': 'ns0__sameLayerAs', 'end': 'ns0__OutputLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasCost', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'ns0__hasCost', 'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__hasCost', 'end': 'ns0__CostFunction'},
#   {'start': 'Resource', 'type': 'rdfs__range', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'rdfs__range', 'end': 'owl__Class'},
#   {'start': 'Resource', 'type': 'rdfs__range', 'end': 'rdfs__Datatype'},
#   {'start': 'Resource', 'type': 'rdfs__domain', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'rdfs__domain', 'end': 'owl__Class'},
#   {'start': 'Resource', 'type': 'rdfs__subPropertyOf', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__ObjectProperty'},
#   {'start': 'Resource',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__AsymmetricProperty'},
#   {'start': 'Resource',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__IrreflexiveProperty'},
#   {'start': 'Resource',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__InverseFunctionalProperty'},
#   {'start': 'Resource',
#    'type': 'ns0__evaluatesUsingIOPipe',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__evaluatesUsingIOPipe',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__evaluatesUsingIOPipe',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'Resource', 'type': 'ns0__hasMetric', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasMetric',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__hasMetric', 'end': 'ns0__Accuracy'},
#   {'start': 'Resource', 'type': 'ns0__hasMetric', 'end': 'ns0__ParzenWindow'},
#   {'start': 'Resource', 'type': 'ns0__evaluatesNetwork', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__evaluatesNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__evaluatesNetwork',
#    'end': 'ns0__Network'},
#   {'start': 'Resource',
#    'type': 'ns0__withTrainingStrategy',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__withTrainingStrategy',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__withTrainingStrategy',
#    'end': 'ns0__TrainingStrategy'},
#   {'start': 'Resource', 'type': 'ns0__evaluatesANNConf', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__evaluatesANNConf',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__evaluatesANNConf',
#    'end': 'ns0__ANNConfiguration'},
#   {'start': 'Resource', 'type': 'ns0__hasLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasLayer', 'end': 'ns0__BatchNormLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasLayer', 'end': 'ns0__DropoutLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasLayer', 'end': 'ns0__CloneLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasLayer', 'end': 'ns0__ConcatLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasInputLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasInputLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasInputLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasOutputLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasOutputLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasOutputLayer',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'Resource', 'type': 'ns0__hasObjective', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasObjective',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasObjective',
#    'end': 'ns0__MinObjectiveFunction'},
#   {'start': 'Resource', 'type': 'ns0__hasTaskType', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTaskType',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__Discrimination'},
#   {'start': 'Resource', 'type': 'ns0__hasTaskType', 'end': 'ns0__Generation'},
#   {'start': 'Resource', 'type': 'ns0__hasTaskType', 'end': 'ns0__Adversarial'},
#   {'start': 'Resource', 'type': 'ns0__hasTaskType', 'end': 'ns0__Clustering'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__SupervisedClassification'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__Reconstruction'},
#   {'start': 'Resource', 'type': 'owl__onProperty', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'owl__onProperty',
#    'end': 'owl__ObjectProperty'},
#   {'start': 'Resource',
#    'type': 'owl__onProperty',
#    'end': 'owl__IrreflexiveProperty'},
#   {'start': 'Resource',
#    'type': 'owl__onProperty',
#    'end': 'owl__AsymmetricProperty'},
#   {'start': 'Resource',
#    'type': 'owl__onProperty',
#    'end': 'owl__FunctionalProperty'},
#   {'start': 'Resource',
#    'type': 'owl__onProperty',
#    'end': 'owl__InverseFunctionalProperty'},
#   {'start': 'Resource', 'type': 'owl__onClass', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'owl__onClass', 'end': 'owl__Class'},
#   {'start': 'Resource', 'type': 'rdfs__subClassOf', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'rdfs__subClassOf', 'end': 'owl__Class'},
#   {'start': 'Resource', 'type': 'rdfs__subClassOf', 'end': 'owl__Restriction'},
#   {'start': 'Resource',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__SoftMax'},
#   {'start': 'Resource',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Tanh'},
#   {'start': 'Resource',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Relu'},
#   {'start': 'Resource',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Sigmoid'},
#   {'start': 'Resource',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Linear'},
#   {'start': 'Resource', 'type': 'ns0__trainedInLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__trainedInLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__trainedInLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__trainedInLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'Resource', 'type': 'ns0__trainedOutLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'Resource', 'type': 'rdf__first', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'rdf__first', 'end': 'owl__ObjectProperty'},
#   {'start': 'Resource', 'type': 'rdf__first', 'end': 'owl__Class'},
#   {'start': 'Resource', 'type': 'rdf__first', 'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'rdf__first',
#    'end': 'ns0__CategoricalCrossEntropy'},
#   {'start': 'Resource', 'type': 'rdf__rest', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'owl__disjointWith', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'owl__disjointWith', 'end': 'owl__Class'},
#   {'start': 'Resource', 'type': 'owl__members', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'Resource', 'type': 'ns0__hasWeights', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasWeights',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasWeights',
#    'end': 'ns0__TrainedWeights'},
#   {'start': 'Resource', 'type': 'ns0__hasNetwork', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__hasNetwork', 'end': 'ns0__Network'},
#   {'start': 'Resource', 'type': 'ns0__hasTrainingStrategy', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'ns0__TrainingStrategy'},
#   {'start': 'Resource', 'type': 'ns0__hasFunction', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasFunction',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__hasFunction', 'end': 'ns0__Gaussian'},
#   {'start': 'Resource', 'type': 'ns0__hasFunction', 'end': 'ns0__Categorical'},
#   {'start': 'Resource', 'type': 'ns0__hasLabels', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLabels',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__hasLabels', 'end': 'ns0__Labelset'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'Resource', 'type': 'ns0__hasRegularizer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasRegularizer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasRegularizer',
#    'end': 'ns0__L2RegularizerFunction'},
#   {'start': 'Resource', 'type': 'ns0__hasLoss', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'ns0__hasLoss', 'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__hasLoss', 'end': 'owl__Class'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLoss',
#    'end': 'ns0__CategoricalCrossEntropy'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLoss',
#    'end': 'ns0__BinaryCrossEntropy'},
#   {'start': 'Resource', 'type': 'ns0__hasLoss', 'end': 'ns0__MSE'},
#   {'start': 'Resource',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'ns0__Momentum'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'ns0__GradientDescent'},
#   {'start': 'Resource', 'type': 'ns0__trainsNetwork', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__trainsNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__trainsNetwork', 'end': 'ns0__Network'},
#   {'start': 'Resource', 'type': 'ns0__nextTrainingStep', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'Resource',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'Resource', 'type': 'ns0__hasDataType', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasDataType',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource', 'type': 'ns0__hasDataType', 'end': 'ns0__Image'},
#   {'start': 'Resource',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'ns0__NumericalDigits'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'ns0__TrainingSession'},
#   {'start': 'Resource', 'type': 'ns0__hasTrainedModel', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'ns0__TrainedModel'},
#   {'start': 'Resource', 'type': 'owl__inverseOf', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'owl__inverseOf',
#    'end': 'owl__ObjectProperty'},
#   {'start': 'Resource',
#    'type': 'owl__inverseOf',
#    'end': 'owl__IrreflexiveProperty'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'ns0__TrainingLoop'},
#   {'start': 'Resource', 'type': 'owl__equivalentClass', 'end': 'Resource'},
#   {'start': 'Resource', 'type': 'owl__equivalentClass', 'end': 'owl__Class'},
#   {'start': 'Resource', 'type': 'ns0__hasTrainingStep', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'Resource',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'Resource', 'type': 'ns0__updatesLayer', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__updatesLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__updatesLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'Resource', 'type': 'ns0__hasStopCondition', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasStopCondition',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasStopCondition',
#    'end': 'ns0__IterateFor'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'Resource', 'type': 'ns0__hasLoopTrainingStep', 'end': 'Resource'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'Resource',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsDataSet',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsDataSet',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsDataSet',
#    'end': 'ns0__Dataset'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsDataSet',
#    'end': 'ns0__RandomNoiseDataset'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsLayer',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__joinsLayer',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__DropoutLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__ConcatLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__DropoutLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__ConcatLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__InputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__DropoutLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'owl__NamedIndividual', 'type': 'ns0__hasCost', 'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasCost',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasCost',
#    'end': 'ns0__CostFunction'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesUsingIOPipe',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesUsingIOPipe',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesUsingIOPipe',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasMetric',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasMetric',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasMetric',
#    'end': 'ns0__Accuracy'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasMetric',
#    'end': 'ns0__ParzenWindow'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesNetwork',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesNetwork',
#    'end': 'ns0__Network'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__withTrainingStrategy',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__withTrainingStrategy',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__withTrainingStrategy',
#    'end': 'ns0__TrainingStrategy'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesANNConf',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesANNConf',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__evaluatesANNConf',
#    'end': 'ns0__ANNConfiguration'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLayer',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLayer',
#    'end': 'ns0__DropoutLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLayer',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLayer',
#    'end': 'ns0__ConcatLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasInputLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasInputLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasInputLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasOutputLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasOutputLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasOutputLayer',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasObjective',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasObjective',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasObjective',
#    'end': 'ns0__MinObjectiveFunction'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__Discrimination'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__Generation'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__Adversarial'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__Clustering'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__SupervisedClassification'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTaskType',
#    'end': 'ns0__Reconstruction'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__SoftMax'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Tanh'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Relu'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Sigmoid'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Linear'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainedInLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainedInLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainedInLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainedInLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasWeights',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasWeights',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasWeights',
#    'end': 'ns0__TrainedWeights'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasNetwork',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasNetwork',
#    'end': 'ns0__Network'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'ns0__TrainingStrategy'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasFunction',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasFunction',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasFunction',
#    'end': 'ns0__Gaussian'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasFunction',
#    'end': 'ns0__Categorical'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLabels',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLabels',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLabels',
#    'end': 'ns0__Labelset'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasRegularizer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasRegularizer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasRegularizer',
#    'end': 'ns0__L2RegularizerFunction'},
#   {'start': 'owl__NamedIndividual', 'type': 'ns0__hasLoss', 'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoss',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoss',
#    'end': 'owl__Class'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoss',
#    'end': 'ns0__CategoricalCrossEntropy'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoss',
#    'end': 'ns0__BinaryCrossEntropy'},
#   {'start': 'owl__NamedIndividual', 'type': 'ns0__hasLoss', 'end': 'ns0__MSE'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'ns0__Momentum'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'ns0__GradientDescent'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainsNetwork',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainsNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__trainsNetwork',
#    'end': 'ns0__Network'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasDataType',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasDataType',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasDataType',
#    'end': 'ns0__Image'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'ns0__NumericalDigits'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'ns0__TrainingSession'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'ns0__TrainedModel'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'ns0__TrainingLoop'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'rdfs__subClassOf',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'rdfs__subClassOf',
#    'end': 'owl__Class'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__updatesLayer',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__updatesLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__updatesLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasStopCondition',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasStopCondition',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasStopCondition',
#    'end': 'ns0__IterateFor'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'Resource'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'owl__NamedIndividual',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsDataSet',
#    'end': 'Resource'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsDataSet',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsDataSet',
#    'end': 'ns0__Dataset'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsDataSet',
#    'end': 'ns0__RandomNoiseDataset'},
#   {'start': 'ns0__DatasetPipe', 'type': 'ns0__joinsLayer', 'end': 'Resource'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsLayer',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'ns0__DatasetPipe',
#    'type': 'ns0__joinsLayer',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__CloneLayer', 'type': 'ns0__nextLayer', 'end': 'Resource'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'ns0__CloneLayer', 'type': 'ns0__sameLayerAs', 'end': 'Resource'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__CloneLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'ns0__MinObjectiveFunction',
#    'type': 'ns0__hasCost',
#    'end': 'Resource'},
#   {'start': 'ns0__MinObjectiveFunction',
#    'type': 'ns0__hasCost',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__MinObjectiveFunction',
#    'type': 'ns0__hasCost',
#    'end': 'ns0__CostFunction'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__range',
#    'end': 'Resource'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__range',
#    'end': 'owl__Class'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__domain',
#    'end': 'Resource'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__domain',
#    'end': 'owl__Class'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'Resource'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__ObjectProperty'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__AsymmetricProperty'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__IrreflexiveProperty'},
#   {'start': 'owl__FunctionalProperty',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'owl__InverseFunctionalProperty'},
# ...
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__ConcatLayer'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__OutputLayer'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__ConcatLayer'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'Resource'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__SoftMax'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Tanh'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Relu'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Sigmoid'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__hasActivationFunction',
#    'end': 'ns0__Linear'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'Resource'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__FullyConnectedLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__TrainedWeights',
#    'type': 'ns0__trainedInLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainedWeights',
#    'type': 'ns0__trainedInLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainedWeights',
#    'type': 'ns0__trainedInLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__TrainedWeights',
#    'type': 'ns0__trainedInLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'ns0__TrainedWeights',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainedWeights',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainedWeights',
#    'type': 'ns0__trainedOutLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'owl__AllDisjointClasses',
#    'type': 'owl__members',
#    'end': 'Resource'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__InputLayer'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__DropoutLayer'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__CloneLayer'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'Resource'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__BatchNormLayer',
#    'type': 'ns0__sameLayerAs',
#    'end': 'ns0__BatchNormLayer'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedXValDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'ns0__Dataset', 'type': 'ns0__hasLabels', 'end': 'Resource'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__hasLabels',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__Dataset', 'type': 'ns0__hasLabels', 'end': 'ns0__Labelset'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedTestDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'ns0__Dataset', 'type': 'ns0__hasDataType', 'end': 'Resource'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__hasDataType',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__Dataset', 'type': 'ns0__hasDataType', 'end': 'ns0__Image'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'Resource'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__hasCharacteristicLabel',
#    'end': 'ns0__NumericalDigits'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'Resource'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__Dataset',
#    'type': 'ns0__derivedTrainingDatasetFrom',
#    'end': 'ns0__Dataset'},
#   {'start': 'ns0__TrainedModel', 'type': 'ns0__hasWeights', 'end': 'Resource'},
#   {'start': 'ns0__TrainedModel',
#    'type': 'ns0__hasWeights',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainedModel',
#    'type': 'ns0__hasWeights',
#    'end': 'ns0__TrainedWeights'},
#   {'start': 'owl__Restriction', 'type': 'owl__onProperty', 'end': 'Resource'},
#   {'start': 'owl__Restriction',
#    'type': 'owl__onProperty',
#    'end': 'owl__ObjectProperty'},
#   {'start': 'owl__Restriction',
#    'type': 'owl__onProperty',
#    'end': 'owl__IrreflexiveProperty'},
#   {'start': 'owl__Restriction',
#    'type': 'owl__onProperty',
#    'end': 'owl__AsymmetricProperty'},
#   {'start': 'owl__Restriction',
#    'type': 'owl__onProperty',
#    'end': 'owl__FunctionalProperty'},
#   {'start': 'owl__Restriction',
#    'type': 'owl__onProperty',
#    'end': 'owl__InverseFunctionalProperty'},
#   {'start': 'owl__Restriction', 'type': 'owl__onClass', 'end': 'Resource'},
#   {'start': 'owl__Restriction', 'type': 'owl__onClass', 'end': 'owl__Class'},
#   {'start': 'ns0__ANNConfiguration',
#    'type': 'ns0__hasNetwork',
#    'end': 'Resource'},
#   {'start': 'ns0__ANNConfiguration',
#    'type': 'ns0__hasNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__ANNConfiguration',
#    'type': 'ns0__hasNetwork',
#    'end': 'ns0__Network'},
#   {'start': 'ns0__ANNConfiguration',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'Resource'},
#   {'start': 'ns0__ANNConfiguration',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__ANNConfiguration',
#    'type': 'ns0__hasTrainingStrategy',
#    'end': 'ns0__TrainingStrategy'},
#   {'start': 'owl__SymmetricProperty',
#    'type': 'rdfs__domain',
#    'end': 'Resource'},
#   {'start': 'owl__SymmetricProperty',
#    'type': 'rdfs__domain',
#    'end': 'owl__Class'},
#   {'start': 'owl__SymmetricProperty',
#    'type': 'rdfs__subPropertyOf',
#    'end': 'Resource'},
#   {'start': 'owl__SymmetricProperty',
#    'type': 'rdfs__range',
#    'end': 'Resource'},
#   {'start': 'owl__SymmetricProperty',
#    'type': 'rdfs__range',
#    'end': 'owl__Class'},
#   {'start': 'ns0__RandomNoiseDataset',
#    'type': 'ns0__hasFunction',
#    'end': 'Resource'},
#   {'start': 'ns0__RandomNoiseDataset',
#    'type': 'ns0__hasFunction',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__RandomNoiseDataset',
#    'type': 'ns0__hasFunction',
#    'end': 'ns0__Gaussian'},
#   {'start': 'ns0__RandomNoiseDataset',
#    'type': 'ns0__hasFunction',
#    'end': 'ns0__Categorical'},
#   {'start': 'ns0__RandomNoiseDataset',
#    'type': 'ns0__hasLabels',
#    'end': 'Resource'},
#   {'start': 'ns0__RandomNoiseDataset',
#    'type': 'ns0__hasLabels',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__RandomNoiseDataset',
#    'type': 'ns0__hasLabels',
#    'end': 'ns0__Labelset'},
#   {'start': 'ns0__CostFunction',
#    'type': 'ns0__hasRegularizer',
#    'end': 'Resource'},
#   {'start': 'ns0__CostFunction',
#    'type': 'ns0__hasRegularizer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__CostFunction',
#    'type': 'ns0__hasRegularizer',
#    'end': 'ns0__L2RegularizerFunction'},
#   {'start': 'ns0__CostFunction', 'type': 'ns0__hasLoss', 'end': 'Resource'},
#   {'start': 'ns0__CostFunction',
#    'type': 'ns0__hasLoss',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__CostFunction', 'type': 'ns0__hasLoss', 'end': 'owl__Class'},
#   {'start': 'ns0__CostFunction',
#    'type': 'ns0__hasLoss',
#    'end': 'ns0__CategoricalCrossEntropy'},
#   {'start': 'ns0__CostFunction',
#    'type': 'ns0__hasLoss',
#    'end': 'ns0__BinaryCrossEntropy'},
#   {'start': 'ns0__CostFunction', 'type': 'ns0__hasLoss', 'end': 'ns0__MSE'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'ns0__Momentum'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__hasTrainingOptimizer',
#    'end': 'ns0__GradientDescent'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__trainsNetwork',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__trainsNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__trainsNetwork',
#    'end': 'ns0__Network'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__updatesLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__updatesLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingle',
#    'type': 'ns0__updatesLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__trainsNetwork',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__trainsNetwork',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__trainsNetwork',
#    'end': 'ns0__Network'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSingleForwardOnly',
#    'type': 'ns0__trainingSingleHasIOPipe',
#    'end': 'ns0__DatasetPipe'},
#   {'start': 'ns0__TrainingStrategy',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingStrategy',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingStrategy',
#    'type': 'ns0__hasPrimaryTrainingSession',
#    'end': 'ns0__TrainingSession'},
#   {'start': 'ns0__TrainingStrategy',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingStrategy',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingStrategy',
#    'type': 'ns0__hasTrainedModel',
#    'end': 'ns0__TrainedModel'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasPrimaryTrainingStep',
#    'end': 'ns0__TrainingLoop'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'},
#   {'start': 'ns0__TrainingSession',
#    'type': 'ns0__hasTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'ns0__ConcatLayer', 'type': 'ns0__nextLayer', 'end': 'Resource'},
#   {'start': 'ns0__ConcatLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__ConcatLayer',
#    'type': 'ns0__nextLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__ConcatLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'Resource'},
#   {'start': 'ns0__ConcatLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__ConcatLayer',
#    'type': 'ns0__previousLayer',
#    'end': 'ns0__FullyConnectedLayer'},
#   {'start': 'ns0__CategoricalCrossEntropy',
#    'type': 'rdfs__subClassOf',
#    'end': 'Resource'},
#   {'start': 'ns0__CategoricalCrossEntropy',
#    'type': 'rdfs__subClassOf',
#    'end': 'owl__Class'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__nextTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasStopCondition',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasStopCondition',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasStopCondition',
#    'end': 'ns0__IterateFor'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasPrimaryLoopTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'Resource'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'owl__NamedIndividual'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'ns0__TrainingSingle'},
#   {'start': 'ns0__TrainingLoop',
#    'type': 'ns0__hasLoopTrainingStep',
#    'end': 'ns0__TrainingSingleForwardOnly'}],
#  'metadata': {'constraint': [{'id': 6,
#     'name': 'n10s_unique_uri',
#     'type': 'UNIQUENESS',
#     'entityType': 'NODE',
#     'labelsOrTypes': ['Resource'],
#     'properties': ['uri'],
#     'ownedIndex': 'n10s_unique_uri',
#     'propertyType': None}],
#   'index': [{'label': 'Resource',
#     'properties': ['uri'],
#     'size': 600,
#     'type': 'RANGE',
#     'valuesSelectivity': 1.0,
#     'distinctValues': 600.0}]}}

# %%
print(queryNeo4j(driver, """
    MATCH (a:Taxonomy)-[r]-(b)
    RETURN a, r, b
"""))
# Out:
# None

# %%
from yfiles_jupyter_graphs import GraphWidget
def showGraph():
    session = driver.session()
    query = """
    MATCH (b)
    WHERE b.uri in ["LossFunction", "TaskCharacterization"]
    MATCH (a)-[r*1..1]->(b)
    RETURN a, r, b
    """
    widget = GraphWidget(graph = session.run(query).graph())
    widget.node_label_mapping = 'uri'
    widget.radial_layout()
    widget.set_sidebar(start_with='Data')
    return widget
    

showGraph()
# Out:
# GraphWidget(layout=Layout(height='650px', width='100%'))

# %%
import csv
from neo4j import GraphDatabase
import networkx as nx

# Step 1: Connect to Neo4j Database
uri = "bolt://localhost:7687"  # Neo4j instance URI
username = "neo4j"  # Your Neo4j username
password = "your_password"  # Your Neo4j password

driver = GraphDatabase.driver(uri, auth=(username, password))

# Step 2: Run the Cypher query to get the data
def run_query(driver):
    query = """
    MATCH (a:Taxonomy)-[r]-(b)
    RETURN a, r, b
    """
    
    with driver.session() as session:
        result = session.run(query)
        # Fetch all results before processing them
        records = list(result)  # This ensures we get all records at once
        return records

# Step 3: Convert Cypher results to NetworkX Graph
def cypher_to_networkx(records):
    G = nx.Graph()
    
    for record in records:
        # Extracting node 'a', relationship 'r', and node 'b'
        a = record["a"]
        b = record["b"]
        r = record["r"]
        
        # Use the 'name' property for node labels
        a_name = a["name"]
        b_name = b["name"]
        
        # Handle multiple layer types if present (split by commas and strip whitespace)
        a_layer_types = a.get("LayerTypes", "").split(",") if "LayerTypes" in a else []
        b_layer_types = b.get("LayerTypes", "").split(",") if "LayerTypes" in b else []
        
        # Clean up and remove extra whitespace
        a_layer_types = [layer_type.strip() for layer_type in a_layer_types]
        b_layer_types = [layer_type.strip() for layer_type in b_layer_types]
        
        # Add nodes with properties (using 'name' for node label)
        G.add_node(a_name, name=a["name"], layer_types=a_layer_types)
        G.add_node(b_name, name=b["name"], layer_types=b_layer_types)
        
        # Handle multiple attributes on edges (e.g., layer types, task types)
        edge_layer_types = r.get("LayerTypes", "").split(",") if "LayerTypes" in r else []
        edge_task_types = r.get("TaskTypes", "").split(",") if "TaskTypes" in r else []
        
        # Clean up and remove extra whitespace for edge attributes
        edge_layer_types = [layer_type.strip() for layer_type in edge_layer_types]
        edge_task_types = [task_type.strip() for task_type in edge_task_types]
        
        # Add edge with properties; aggregate data for edges with the same nodes
        if G.has_edge(a_name, b_name):
            # If an edge already exists, update the edge's properties by appending new data
            G[a_name][b_name]["layer_types"].extend(edge_layer_types)
            G[a_name][b_name]["task_types"].extend(edge_task_types)
            # Also, concatenate relationship types
            G[a_name][b_name]["relationships"].add(r.type)
        else:
            # If edge doesn't exist, create a new edge with the properties
            G.add_edge(a_name, b_name, type=r.type, weight=r.get("weight", 1),
                       layer_types=edge_layer_types, task_types=edge_task_types,
                       relationships={r.type})  # Store relationship type in a set for uniqueness
        
    # After adding all edges, we can ensure no duplicates by converting lists to sets for both task_types and layer_types
    for u, v, data in G.edges(data=True):
        data["layer_types"] = list(set(data["layer_types"]))  # Remove duplicates by converting to a set
        data["task_types"] = list(set(data["task_types"]))  # Remove duplicates by converting to a set
        data["relationships"] = list(data["relationships"])  # Ensure relationships are a list for CSV export
        
    return G

# Step 4: Export Node and Edge Data to a Single CSV
def export_graph_to_csv(G, filename):
    with open(filename, mode="w", newline="") as file:
        writer = csv.writer(file)
        
        # Write Nodes Table
        writer.writerow(["# Nodes Table"])  # Optional table header separator
        writer.writerow(["Node Name", "LayerTypes"])  # Node CSV headers (removed ItemState and Label)
        for node, data in G.nodes(data=True):
            # Join the layer types into a single string if multiple types are present
            layer_types = ", ".join(data["layer_types"])
            writer.writerow([node, layer_types])  # Write node data
        
        # Add a separator between nodes and edges (a blank line here)
        writer.writerow([])
        
        # Write Edges Table
        writer.writerow(["# Edges Table"])  # Optional table header separator
        writer.writerow(["Source Node", "Target Node", "Relationship Type"])  # Edge CSV headers (removed LayerTypes, TaskTypes, Weight)
        for u, v, data in G.edges(data=True):
            # Join all relationship types into a comma-separated string
            relationship_types = ", ".join(data["relationships"])
            writer.writerow([u, v, relationship_types])  # Write edge data

# Run the Cypher query and convert to NetworkX graph
records = run_query(driver)
G = cypher_to_networkx(records)

# Export nodes and edges to a single CSV file
export_graph_to_csv(G, "graph_data.csv")

# Close the connection
driver.close()
